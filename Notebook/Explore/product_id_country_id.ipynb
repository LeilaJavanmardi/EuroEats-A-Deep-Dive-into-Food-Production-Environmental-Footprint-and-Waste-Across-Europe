# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_WFP=pd.read_csv("world_food_production.csv")
data_WFP
# Out:
#             Entity  Year  Maize Production (tonnes)  \
# 0      Afghanistan  1961                   700000.0
# 1      Afghanistan  1962                   700000.0
# 2      Afghanistan  1963                   713000.0
# 3      Afghanistan  1964                   720000.0
# 4      Afghanistan  1965                   720000.0
# ...            ...   ...                        ...
# 11907     Zimbabwe  2017                  1532572.0
# 11908     Zimbabwe  2018                  1560100.0
# 11909     Zimbabwe  2019                   773976.0
# 11910     Zimbabwe  2020                  1202347.0
# 11911     Zimbabwe  2021                  1469664.0
#
#        Rice  Production ( tonnes)  Yams  Production (tonnes)  \
# 0                       319000.00               7.467702e+06
# 1                       319000.00               7.420515e+06
# 2                       319000.00               8.479074e+06
# 3                       380000.00               9.113779e+06
# ...

# %%
region = ['Southern Europe', 'Western Europe','Eastern Europe', 'Northern Europe']

# %%
europe = ['Albania', 'Andorra', 'Austria', 'Belarus', 'Belgium',
       'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Czechia',
       'Denmark', 'Estonia', 'Faroe Islands', 'Finland', 'France',
       'Germany', 'Gibraltar', 'Greece', 'Hungary', 'Iceland', 'Ireland',
       'Isle of Man', 'Italy', 'Latvia', 'Liechtenstein', 'Lithuania',
       'Luxembourg', 'Malta', 'Monaco', 'Montenegro', 'Netherlands',
       'North Macedonia', 'Norway', 'Poland', 'Portugal',
       'Republic of Moldova', 'Romania', 'Russian Federation',
       'San Marino', 'Serbia', 'Slovakia', 'Slovenia', 'Spain', 'Sweden',
       'Switzerland', 'Ukraine', 'United Kingdom']        
fil_WFP = data_WFP[data_WFP['Entity'].isin(europe)]
fil_WFP.Entity.unique()
fil_WFP.Entity.nunique()
# Out:
# 35

# %%
fil_WFP.shape
# Out:
# (1262, 24)

# %%
fil_WFP.Year.unique()
# Out:
# array([1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018, 2019, 2020, 2021])

# %%
years = [2000, 2001, 2002, 2003, 2004,
       2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
       2016, 2017, 2018, 2019, 2020, 2021]
fil_WFP = fil_WFP[fil_WFP['Year'].isin(years)]
fil_WFP
fil_WFP1 = fil_WFP[fil_WFP['Year']==2003]
#fil_WFP1.columns
fil_WFP1
# Out:
#                        Entity  Year  Maize Production (tonnes)  \
# 225                   Albania  2003                   206900.0
# 799                   Austria  2003                  1707771.0
# 1042                  Belarus  2003                    50156.0
# 1064                  Belgium  2003                   554743.0
# 1377   Bosnia and Herzegovina  2003                   545059.0
# 1560                 Bulgaria  2003                  1161107.0
# 2718                  Croatia  2003                  1279617.0
# 2808                  Czechia  2003                   476371.0
# 2932                  Denmark  2003                        0.0
# 4045                   France  2003                 12045464.0
# 4294                  Germany  2003                  3421642.0
# 4416                   Greece  2003                  2503784.5
# 4982                  Hungary  2003                  4532147.0
# 5352                    Italy  2003                  8702288.0
# ...

# %%
# List of columns and their corresponding replacement values
columns_values_mapping = {
    'Maize Production (tonnes)': 1,
    'Rice  Production ( tonnes)': 2,
    'Tomatoes Production (tonnes)': 3,
    'Tea  Production ( tonnes )': 4,
    'Sweet potatoes  Production (tonnes)': 5,
    'Sunflower seed  Production (tonnes)': 6,
    'Sugar cane Production (tonnes)': 7,
    'Soybeans  Production (tonnes)': 8,
    'Rye  Production (tonnes)': 9,
    'Potatoes  Production (tonnes)': 10,
    'Oranges  Production (tonnes)': 11,
    'Peas, dry Production ( tonnes)': 12,
    'Palm oil  Production (tonnes)': 13,
    'Grapes  Production (tonnes)': 14,
    'Coffee, green Production ( tonnes)': 15,
    'Cocoa beans Production (tonnes)': 16,
    'Meat, chicken  Production (tonnes)': 21,
    'Bananas  Production ( tonnes)': 17,
    'Avocados Production (tonnes)': 18,
    'Apples Production (tonnes)': 19,
    'Wheat Production (tonnes)': 20,
    'Yams  Production (tonnes)': 22
}

# Iterate over each column and replace values excluding 0.0
for column, value in columns_values_mapping.items():
    mask = (fil_WFP1[column] != 0.0) & (~fil_WFP1[column].isna())
    fil_WFP1.loc[mask, column] = value

# %% [markdown]
# fil_WFP1.loc[~fil_WFP1['Maize Production (tonnes)'].isna(), 'Maize Production (tonnes)'] = 1
# fil_WFP1.loc[~fil_WFP1['Rice  Production ( tonnes)'].isna(), 'Rice  Production ( tonnes)'] = 2
# fil_WFP1.loc[~fil_WFP1['Tomatoes Production (tonnes)'].isna(), 'Tomatoes Production (tonnes)'] = 3
# fil_WFP1.loc[~fil_WFP1['Tea  Production ( tonnes )'].isna(), 'Tea  Production ( tonnes )'] = 4
# fil_WFP1.loc[~fil_WFP1['Sweet potatoes  Production (tonnes)'].isna(), 'Sweet potatoes  Production (tonnes)'] = 5
# fil_WFP1.loc[~fil_WFP1['Sunflower seed  Production (tonnes)'].isna(), 'Sunflower seed  Production (tonnes)'] = 6
# fil_WFP1.loc[~fil_WFP1['Sugar cane Production (tonnes)'].isna(), 'Sugar cane Production (tonnes)'] = 7
# fil_WFP1.loc[~fil_WFP1['Soybeans  Production (tonnes)'].isna(), 'Soybeans  Production (tonnes)'] = 8
# fil_WFP1.loc[~fil_WFP1['Rye  Production (tonnes)'].isna(), 'Rye  Production (tonnes)'] = 9
# fil_WFP1.loc[~fil_WFP1['Potatoes  Production (tonnes)'].isna(), 'Potatoes  Production (tonnes)'] = 10
# fil_WFP1.loc[~fil_WFP1['Oranges  Production (tonnes)'].isna(), 'Oranges  Production (tonnes)'] = 11
# fil_WFP1.loc[~fil_WFP1['Peas, dry Production ( tonnes)'].isna(), 'Peas, dry Production ( tonnes)'] = 12
# fil_WFP1.loc[~fil_WFP1['Palm oil  Production (tonnes)'].isna(), 'Palm oil  Production (tonnes)'] = 13
# fil_WFP1.loc[~fil_WFP1['Grapes  Production (tonnes)'].isna(), 'Grapes  Production (tonnes)'] = 14
# fil_WFP1.loc[~fil_WFP1['Coffee, green Production ( tonnes)'].isna(), 'Coffee, green Production ( tonnes)'] = 15
# fil_WFP1.loc[~fil_WFP1['Cocoa beans Production (tonnes)'].isna(), 'Cocoa beans Production (tonnes)'] = 16
# fil_WFP1.loc[~fil_WFP1['Bananas  Production ( tonnes)'].isna(), 'Bananas  Production ( tonnes)'] = 17
# fil_WFP1.loc[~fil_WFP1['Avocados Production (tonnes)'].isna(), 'Avocados Production (tonnes)'] = 18
# fil_WFP1.loc[~fil_WFP1['Apples Production (tonnes)'].isna(), 'Apples Production (tonnes)'] = 19
# fil_WFP1.loc[~fil_WFP1['Wheat Production (tonnes)'].isna(), 'Wheat Production (tonnes)'] = 20
# fil_WFP1.loc[~fil_WFP1['Meat, chicken  Production (tonnes)'].isna(), 'Meat, chicken  Production (tonnes)'] = 21
# fil_WFP1.loc[~fil_WFP1['Yams  Production (tonnes)'].isna(), 'Yams  Production (tonnes)'] = 22

# %%
fil_WFP1.drop(columns='Year', inplace=True)
# Out:
# /var/folders/7n/f1mvr75d23s1g67jsx9pn8hr0000gn/T/ipykernel_6125/56950800.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fil_WFP1.drop(columns='Year', inplace=True)

# %%
fil_WFP1
# Out:
#                        Entity  Maize Production (tonnes)  \
# 225                   Albania                        1.0
# 799                   Austria                        1.0
# 1042                  Belarus                        1.0
# 1064                  Belgium                        1.0
# 1377   Bosnia and Herzegovina                        1.0
# 1560                 Bulgaria                        1.0
# 2718                  Croatia                        1.0
# 2808                  Czechia                        1.0
# 2932                  Denmark                        0.0
# 4045                   France                        1.0
# 4294                  Germany                        1.0
# 4416                   Greece                        1.0
# 4982                  Hungary                        1.0
# 5352                    Italy                        1.0
# 6106                Lithuania                        1.0
# ...

# %%
# Define the mapping of old column names to new column names
column_mapping = {
    'Maize Production (tonnes)': 'Maize product_id',
    'Rice  Production ( tonnes)': 'Rice product_id',
    'Yams  Production (tonnes)': 'Yams product_id',
    'Wheat Production (tonnes)': 'Wheat product_id',
    'Tomatoes Production (tonnes)': 'Tomatoes product_id',
    'Tea  Production ( tonnes )': 'Tea product_id',
    'Sweet potatoes  Production (tonnes)': 'Sweet potatoes product_id',
    'Sunflower seed  Production (tonnes)': 'Sunflower seed product_id',
    'Sugar cane Production (tonnes)': 'Sugar cane product_id',
    'Soybeans  Production (tonnes)': 'Soybeans product_id',
    'Rye  Production (tonnes)': 'Rye product_id',
    'Potatoes  Production (tonnes)': 'Potatoes product_id',
    'Oranges  Production (tonnes)': 'Oranges product_id',
    'Peas, dry Production ( tonnes)': 'Peas, dry product_id',
    'Palm oil  Production (tonnes)': 'Palm oil product_id',
    'Grapes  Production (tonnes)': 'Grapes product_id',
    'Coffee, green Production ( tonnes)': 'Coffee product_id',
    'Cocoa beans Production (tonnes)': 'Cocoa beans product_id',
    'Meat, chicken  Production (tonnes)': 'Meat, chicken product_id',
    'Bananas  Production ( tonnes)': 'Bananas product_id',
    'Avocados Production (tonnes)': 'Avocados product_id',
    'Apples Production (tonnes)': 'Apples product_id'
}

# Rename the columns inplace
fil_WFP1.rename(columns=column_mapping, inplace=True)
# Out:
# /var/folders/7n/f1mvr75d23s1g67jsx9pn8hr0000gn/T/ipykernel_6125/1040437230.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fil_WFP1.rename(columns=column_mapping, inplace=True)

# %%
fil_WFP1.reset_index(inplace=True)
fil_WFP1
# Out:
#     level_0  index                  Entity  Maize product_id  Rice product_id  \
# 0         0    225                 Albania               1.0              0.0
# 1         1    799                 Austria               1.0              2.0
# 2         2   1042                 Belarus               1.0              2.0
# 3         3   1064                 Belgium               1.0              2.0
# 4         4   1377  Bosnia and Herzegovina               1.0              2.0
# 5         5   1560                Bulgaria               1.0              2.0
# 6         6   2718                 Croatia               1.0              2.0
# 7         7   2808                 Czechia               1.0              2.0
# 8         8   2932                 Denmark               0.0              2.0
# 9         9   4045                  France               1.0              2.0
# 10       10   4294                 Germany               1.0              2.0
# ...

# %%
fil_WFP1['Country_Id'] = fil_WFP1.index + 1
# Out:
# /var/folders/7n/f1mvr75d23s1g67jsx9pn8hr0000gn/T/ipykernel_6125/1493953773.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fil_WFP1['Country_Id'] = fil_WFP1.index + 1

# %%
fil_WFP1.drop(columns=['index','level_0'], inplace=True)
# Out:
# /var/folders/7n/f1mvr75d23s1g67jsx9pn8hr0000gn/T/ipykernel_6125/3545474977.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fil_WFP1.drop(columns=['index','level_0'], inplace=True)
#                     Entity  Maize product_id  Rice product_id  \
# 0                  Albania               1.0              0.0
# 1                  Austria               1.0              2.0
# 2                  Belarus               1.0              2.0
# 3                  Belgium               1.0              2.0
# 4   Bosnia and Herzegovina               1.0              2.0
# 5                 Bulgaria               1.0              2.0
# 6                  Croatia               1.0              2.0
# 7                  Czechia               1.0              2.0
# ...

# %%
fil_WFP1.rename(columns={'Entity': 'Country'}, inplace=True)
# Out:
# /var/folders/7n/f1mvr75d23s1g67jsx9pn8hr0000gn/T/ipykernel_6125/3171469927.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fil_WFP1.rename(columns={'Entity': 'Country'}, inplace=True)

# %%
fil_WFP1
# Out:
#                    Country  Maize product_id  Rice product_id  \
# 0                  Albania               1.0              0.0
# 1                  Austria               1.0              2.0
# 2                  Belarus               1.0              2.0
# 3                  Belgium               1.0              2.0
# 4   Bosnia and Herzegovina               1.0              2.0
# 5                 Bulgaria               1.0              2.0
# 6                  Croatia               1.0              2.0
# 7                  Czechia               1.0              2.0
# 8                  Denmark               0.0              2.0
# 9                   France               1.0              2.0
# 10                 Germany               1.0              2.0
# 11                  Greece               1.0              2.0
# 12                 Hungary               1.0              2.0
# 13                   Italy               1.0              2.0
# ...

# %% [markdown]
# fil_WFP_Avg_year = fil_WFP.mean()
# fil_WFP_Avg_year
# fil_WFP_Avg_year = fil_WFP.drop(columns=['Entity']).mean()

# %%
fil_WFP1.to_csv('country_product_id.csv', index=False)
